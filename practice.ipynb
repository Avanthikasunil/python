# %%
num = int(input("enter a number:"))
if num % 7 == 0:
    print("divisible by 7")
else:
    print("not divisble by 7")
# Out:
# enter a number:5
# not divisble by 7

# %%
ch = input("enter a charcter:")
if ch in "aeiou":
    print("it is vowel")
else:
    print("it is not a vowel")
# Out:
# enter a charcter:u
# it is vowel

# %%
age = int(input("enter the age:"))
if age >= 18:
    print("eligible for driving")
else:
    print("not eligible for driving")
# Out:
# enter the age:12
# not eligible for driving

# %%
string1 = int(input("enter the first number:"))
string2 = int(input("enter the second number:"))
if string1 == string2:
    print("both are equal")
else:
    print("both are not equal")
# Out:
# enter the first number:41
# enter the second number:25
# both are not equal

# %%
amount = int(input("enter the amount:"))
if amount >= 5000:
    print("eligible for discount")
else:
    print("not eligible for discount")
# Out:
# enter the amount:2000
# not eligible for discount

# %%
num = int(input("enter the range:"))
if num >= 10 and num <= 100:
    print("number is lies between 10 and 100")
else:
    print("number doesnot lies between 10 and 100")
# Out:
# enter the range:101
# number doesnot lies between 10 and 100

# %%
attendence = int(input("enter the percentage:"))
if attendence >= 75:
    print("eligible for exam")
else:
    print("npt eligible for exam")
# Out:
# enter the percentage:80
# eligible for exam

# %%
ch = (input("enter the alphabet:"))
if ch.isupper():
    print("it is a uppercase letter")
else:
    print("it is lowercase letter")
# Out:
# enter the alphabet:A
# it is a uppercase letter

# %%
num = int(input("enter the number:"))
if num >= 100 and num <= 999:
    print("it is a three digit number")
else:
    print("it is not a three digit number")
# Out:
# enter the number:5555
# it is not a three digit number

# %%
data = int(input("enter the mobiledata used in GB:"))
if data <= 2:
    print("low usage")
elif data <= 5:
    print("moderate")
else:
    print("high usage")
# Out:
# enter the mobiledata used in GB:3
# moderate
