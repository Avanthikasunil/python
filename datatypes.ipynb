# %%
marks = [50,60,80,90,40]
print(marks[0])
# Out:
# 50

# %%
number = [50,60,80,90,40]
number.append(70)
print(number)
# Out:
# [50, 60, 80, 90, 40, 70]

# %%
number = (50,60,80,90,40)
print(number[2])
# Out:
# 80

# %%
number = {50,60,60,80,90,40}
print(number)
# Out:
# {80, 50, 40, 90, 60}

# %%
student = {"name":"anu",
          "age":"20",
          "mark":"45"}
print(student["name"])
# Out:
# anu

# %%
string = "python"
print(string[0])
print(string[5])
# Out:
# p
# n
